# %% [markdown]
# <a href="https://colab.research.google.com/github/Efremenkof/Test/blob/master/Project_Efremenko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Page:
    bgcolor= '#FFFFFF'
    text= '#000000'
    def __init__(self, num):
        self.num = num

    def Head(self):
        f.write('<head>\n')
        page.Title()
        f.write('</head>\n')
        
    def Title(self):
        f.write('<title>')
        print('Введите название страницы')
        namepage=input()
        f.write(namepage)
        f.write('</title>\n')
    def Bodyopen(self, bgcolor, text):
        f.write('<body bgcolor="')
        self.bgcolor = bgcolor
        self.text = text
        f.write(bgcolor)
        f.write('" text="')
        f.write(text)
        f.write('">\n')
    def Img(self):
        f.write('<img src="')
        print('Введите название изображения')        
        f.write(input())        
        f.write('">\n')
    def P(self):
        f.write('<p>')
        f.write(input())
        f.write('</p>\n')
    def H1(self):
        f.write('<h1>')
        print('Введите заголовок текста страницы')
        f.write(input())
        f.write('</h1>\n')
    def Namestr(self):
        f.write('<h2>')
        f.write('Список источников')
        f.write('</h2>\n')
    def A(self):
        print('Введите ссылки на использованную литературу')
        tt=input()
        f.write('<a href="')
        f.write(tt)
        f.write('">')
        f.write(tt)
        f.write('</a>')
i=0
while True:
    i=i+1
    print('Хотите ли Вы создать страницу html? (<<Да>> или <<Нет>>)')
    reply = input()
    if reply == 'Нет':
        break
    if reply == 'Да':
        print('Введите названия файла')
        namef= input()
        f = open(namef, 'w')
        f.write('<html>\n')
        page = Page(i)
        page.Head()
        print('Поменять цвет фона?')
        bgcolor1='#FFFFFF'
        text1='#000000'
        if(input()=='Да'):
            print('Введите код цвета')
            bgcolor1=input()
        print('Поменять цвет всего текста?')
        if(input()=='Да'):
            print('Введите код цвета')
            text1=input()
        page.Bodyopen(bgcolor1, text1)
        page.H1()
        print('Пишите основной текст')
        while True:
            page.P()
            print('Будете ли вы ещё писать текст?')
            if(input() == 'Да'):
                pass
            else:
                break
        print('Будете ли вы вставлять изображение?')
        if(input() == 'Да'):
            page.Img()
        page.Namestr()
        page.A()
        f.write('</html>')
        f.close()
